# %%
import requests

response = requests.get("https://en.wikipedia.org/wiki/J._M._W._Turner")

# %%
import bs4 
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
image_info = soup.select('.image')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>J. M. W. Turner - Wikipedia</title>
# ...

# %%
image_info
# Out:
# [<a class="image" href="/wiki/File:Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg"><img alt="Joseph Mallord William Turner Self Portrait 1799.jpg" data-file-height="1536" data-file-width="1182" decoding="async" height="286" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg/220px-Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg/330px-Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg/440px-Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg 2x" width="220"/></a>,
# ...

# %%
len(image_info)
# Out:
# 23

# %%
src_list = [img_tag.find('img')['src'] for img_tag in image_info]
print(src_list)
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg/220px-Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/5/5f/DV307_no.70_House_where_Turner_was_born%2C_from_a_print.png/170px-DV307_no.70_House_where_Turner_was_born%2C_from_a_print.png', '//upload.wikimedia.org/wikipedia/commons/thumb/9/99/Joseph_Mallord_William_Turner_%28British_-_Modern_Rome-Campo_Vaccino_-_Google_Art_Project.jpg/220px-Joseph_Mallord_William_Turner_%28British_-_Modern_Rome-Campo_Vaccino_-_Google_Art_Project.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Joseph_Mallord_William_Turner_-_Fishermen_at_Sea_-_Google_Art_Project.jpg/220px-Joseph_Mallord_William_Turner_-_Fishermen_at_Sea_-_Google_Art_Project.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Portrait_of_J._M._W._Turner%2C_R.A._making_his_sketch_for_the_celebrated_picture_of_Mercury_%26_Argus_%284674619%29.jpg/170px-Portrait_of_
# ...

# %%
links = []

for link in image_info:
    src = link.find('img')['src']
    if type(src) is str:
        links.append("https:" + src)

# %%
import urllib.request  
import urllib.parse 
from urllib.error import HTTPError 
import time 
import random as r

# %%
def download(url, full_path):
    try:
        urllib.request.urlretrieve(url, full_path)
        time.sleep(r.randint(1, 5))
    except urllib.error.HTTPError as err:
        print(err.code)
        pass

# %%
for index, url in enumerate(links):
    print(url)
    file_name = 'img_' + str(index) + '.jpg'
    file_path = 'images/'    
    full_path = '{}{}'.format(file_path, file_name)
    print(file_name)
    download(url, full_path)
# Out:
# https://upload.wikimedia.org/wikipedia/commons/thumb/1/19/Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg/220px-Joseph_Mallord_William_Turner_Self_Portrait_1799.jpg
# img_0.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/DV307_no.70_House_where_Turner_was_born%2C_from_a_print.png/170px-DV307_no.70_House_where_Turner_was_born%2C_from_a_print.png
# img_1.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Joseph_Mallord_William_Turner_%28British_-_Modern_Rome-Campo_Vaccino_-_Google_Art_Project.jpg/220px-Joseph_Mallord_William_Turner_%28British_-_Modern_Rome-Campo_Vaccino_-_Google_Art_Project.jpg
# img_2.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Joseph_Mallord_William_Turner_-_Fishermen_at_Sea_-_Google_Art_Project.jpg/220px-Joseph_Mallord_William_Turner_-_Fishermen_at_Sea_-_Google_Art_Project.jpg
# img_3.jpg
# ...
